# %%
import pandas as pd
from functools import reduce

# %%
df = pd.read_csv(
    "microdados_ed_basica_2023.csv", encoding="ISO-8859-1", sep=";", low_memory=False
)

# %%
df.columns
# Out:
# Index(['NU_ANO_CENSO', 'NO_REGIAO', 'CO_REGIAO', 'NO_UF', 'SG_UF', 'CO_UF',
#        'NO_MUNICIPIO', 'CO_MUNICIPIO', 'NO_REGIAO_GEOG_INTERM',
#        'CO_REGIAO_GEOG_INTERM',
#        ...
#        'QT_TUR_BAS_D', 'QT_TUR_BAS_N', 'QT_TUR_BAS_EAD', 'QT_TUR_INF_INT',
#        'QT_TUR_INF_CRE_INT', 'QT_TUR_INF_PRE_INT', 'QT_TUR_FUND_INT',
#        'QT_TUR_FUND_AI_INT', 'QT_TUR_FUND_AF_INT', 'QT_TUR_MED_INT'],
#       dtype='object', length=408)

# %%
df1 = df[["CO_ENTIDADE", "TP_DEPENDENCIA"]]

# %%
# Lista para armazenar os valores
dependencia = []

# Iterar pelas linhas do DataFrame
for _, row in df1.iterrows():
    if row["TP_DEPENDENCIA"] == 1:
        dependencia.append("Federal")
    elif row["TP_DEPENDENCIA"] == 2:
        dependencia.append("Estadual")
    elif row["TP_DEPENDENCIA"] == 3:
        dependencia.append("Municipal")
    else:
        dependencia.append("Privada")

# Adicionar a nova coluna ao DataFrame
df1["DEPENDENCIA"] = dependencia
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\694928164.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["DEPENDENCIA"] = dependencia

# %%
df1 = df1.drop(["TP_DEPENDENCIA"], axis=1)

# %%
df1.to_csv("estadual_municipal_privada.csv", index=False)

# %%
df2 = df[["NO_ENTIDADE", "CO_ENTIDADE", "TP_SITUACAO_FUNCIONAMENTO"]]

# %%
# Lista para armazenar os valores
atividade = []

# Iterar pelas linhas do DataFrame
for _, row in df2.iterrows():
    if row["TP_SITUACAO_FUNCIONAMENTO"] == 1:
        atividade.append("Em atividade")
    elif row["TP_SITUACAO_FUNCIONAMENTO"] == 2:
        atividade.append("Paralisada")
    else:
        atividade.append("Extinta")

# Adicionar a nova coluna ao DataFrame
df2["ATIVIDADE"] = atividade
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\3832035466.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["ATIVIDADE"] = atividade

# %%
df2 = df2.drop(["TP_SITUACAO_FUNCIONAMENTO"], axis=1)

# %%
df2.to_csv("atividade_paralisada_extinta.csv", index=False)

# %%
df3 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_VINCULO_SECRETARIA_EDUCACAO",
        "IN_VINCULO_SEGURANCA_PUBLICA",
        "IN_VINCULO_SECRETARIA_SAUDE",
        "IN_VINCULO_OUTRO_ORGAO",
    ]
]

# %%
df3["IN_VINCULO_SEGURANCA_PUBLICA"].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df3["IN_VINCULO_SECRETARIA_SAUDE"].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df3["IN_VINCULO_OUTRO_ORGAO"].unique()
# Out:
# array([ 0., nan,  1.])

# %%
# Lista para armazenar os valores
vinculo = []

# Iterar pelas linhas do DataFrame
for _, row in df3.iterrows():
    if row["IN_VINCULO_SEGURANCA_PUBLICA"] == 1.0:
        vinculo.append("Órgão de Segurança Pública")
    elif row["IN_VINCULO_SECRETARIA_SAUDE"] == 1.0:
        vinculo.append("Secretaria de Saúde")
    elif row["IN_VINCULO_SECRETARIA_EDUCACAO"] == 1.0:
        vinculo.append("Secretaria de Educação")
    elif row["IN_VINCULO_OUTRO_ORGAO"] == 1.0:
        vinculo.append("Outro Órgão Público")
    else:
        vinculo.append("Não")

# Adicionar a nova coluna ao DataFrame
df3["VÍNCULOS_PUBLICOS"] = vinculo
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\1249707319.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["VÍNCULOS_PUBLICOS"] = vinculo

# %%
df3 = df3.drop(
    [
        "IN_VINCULO_SEGURANCA_PUBLICA",
        "IN_VINCULO_SECRETARIA_EDUCACAO",
        "IN_VINCULO_SECRETARIA_SAUDE",
        "IN_VINCULO_OUTRO_ORGAO",
    ],
    axis=1,
)

# %%
df3.to_csv("vinculos_publicos1.csv", index=False)

# %%
df4 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_MANT_ESCOLA_PRIVADA_EMP",
        "IN_MANT_ESCOLA_PRIVADA_ONG",
        "IN_MANT_ESCOLA_PRIVADA_OSCIP",
        "IN_MANT_ESCOLA_PRIV_ONG_OSCIP",
        "IN_MANT_ESCOLA_PRIVADA_SIND",
        "IN_MANT_ESCOLA_PRIVADA_SIST_S",
        "IN_MANT_ESCOLA_PRIVADA_S_FINS",
    ]
]

# %%
df4["IN_MANT_ESCOLA_PRIVADA_EMP"].unique()
# Out:
# array([nan,  1.,  0.])

# %%
# Lista para armazenar os valores
mantenedor = []

# Iterar pelas linhas do DataFrame
for _, row in df4.iterrows():
    if row["IN_MANT_ESCOLA_PRIVADA_EMP"] == 1.0:
        mantenedor.append("Empresa do setor privado")
    elif row["IN_MANT_ESCOLA_PRIVADA_ONG"] == 1.0:
        mantenedor.append("Organização Não Governamental - ONG")
    elif row["IN_MANT_ESCOLA_PRIVADA_OSCIP"] == 1.0:
        mantenedor.append("Organização da Sociedade Civil de Interesse Público - OSCIP")
    elif row["IN_MANT_ESCOLA_PRIVADA_SIND"] == 1.0:
        mantenedor.append(
            "Sindicatos de trabalhadores ou patronais, associações e cooperativas"
        )
    elif row["IN_MANT_ESCOLA_PRIVADA_SIST_S"] == 1.0:
        mantenedor.append("Sistema S (Sesi, Senai, Sesc, outros)")
    elif row["IN_MANT_ESCOLA_PRIVADA_S_FINS"] == 1.0:
        mantenedor.append("Instituições sem fins lucrativos")
    else:
        mantenedor.append("Empresa do setor privado")

# Adicionar a nova coluna ao DataFrame
df4["MANTENEDOR_ESCOLA_PRIVADA"] = mantenedor
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\3735930546.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["MANTENEDOR_ESCOLA_PRIVADA"] = mantenedor

# %%
df4 = df4.drop(
    [
        "IN_MANT_ESCOLA_PRIVADA_EMP",
        "IN_MANT_ESCOLA_PRIVADA_ONG",
        "IN_MANT_ESCOLA_PRIVADA_OSCIP",
        "IN_MANT_ESCOLA_PRIV_ONG_OSCIP",
        "IN_MANT_ESCOLA_PRIVADA_SIND",
        "IN_MANT_ESCOLA_PRIVADA_SIST_S",
        "IN_MANT_ESCOLA_PRIVADA_S_FINS",
    ],
    axis=1,
)

# %%
df4.to_csv("mantenedor_privada.csv", index=False)

# %%
df5 = df[["NO_ENTIDADE", "CO_ENTIDADE", "TP_OCUPACAO_PREDIO_ESCOLAR"]]

# %%
# Lista para armazenar os valores
predio_escolar = []

# Iterar pelas linhas do DataFrame
for _, row in df5.iterrows():
    if row["TP_OCUPACAO_PREDIO_ESCOLAR"] == 1:
        predio_escolar.append("Próprio")
    elif row["TP_OCUPACAO_PREDIO_ESCOLAR"] == 2:
        predio_escolar.append("Alugado")
    elif row["TP_OCUPACAO_PREDIO_ESCOLAR"] == 3:
        predio_escolar.append("Cedido")
    else:
        predio_escolar.append("Indefinido")

# Adicionar a nova coluna ao DataFrame
df5["PREDIO_ESCOLAR"] = predio_escolar
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\1740080905.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["PREDIO_ESCOLAR"] = predio_escolar

# %%
df5 = df5.drop(["TP_OCUPACAO_PREDIO_ESCOLAR"], axis=1)

# %%
df5.to_csv("predio_escolar.csv", index=False)

# %%
df6 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_LOCAL_FUNC_SOCIOEDUCATIVO",
        "IN_LOCAL_FUNC_UNID_PRISIONAL",
        "IN_LOCAL_FUNC_PRISIONAL_SOCIO",
        "IN_LOCAL_FUNC_GALPAO",
        "TP_OCUPACAO_GALPAO",
        "IN_LOCAL_FUNC_SALAS_OUTRA_ESC",
        "IN_LOCAL_FUNC_OUTROS",
        "IN_PREDIO_COMPARTILHADO",
    ]
]

# %%
# Lista para armazenar os valores
local = []

# Iterar pelas linhas do DataFrame
for _, row in df6.iterrows():
    if row["IN_LOCAL_FUNC_SOCIOEDUCATIVO"] == 1:
        local.append("Unidade de Atendimento socioeducativo")
    elif row["IN_LOCAL_FUNC_UNID_PRISIONAL"] == 1:
        local.append("Unidade Prisional")
    elif row["IN_LOCAL_FUNC_PRISIONAL_SOCIO"] == 1:
        local.append("Unidade de atendimento socioeducativo")
    elif row["IN_LOCAL_FUNC_GALPAO"] == 1:
        local.append("Galpão/Rancho/Paiol/Barracão")
    elif row["IN_LOCAL_FUNC_SALAS_OUTRA_ESC"] == 1:
        local.append("Salas em outra escola")
    elif row["IN_PREDIO_COMPARTILHADO"] == 1:
        local.append("Prédio compartilhado com outra escola")
    else:
        local.append("Outros")

# Adicionar a nova coluna ao DataFrame
df6["LOCAL_ESCOLAR"] = local
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\3846497367.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6["LOCAL_ESCOLAR"] = local

# %%
df6 = df6.drop(
    [
        "IN_LOCAL_FUNC_SOCIOEDUCATIVO",
        "IN_LOCAL_FUNC_UNID_PRISIONAL",
        "IN_LOCAL_FUNC_PRISIONAL_SOCIO",
        "IN_LOCAL_FUNC_GALPAO",
        "TP_OCUPACAO_GALPAO",
        "IN_LOCAL_FUNC_SALAS_OUTRA_ESC",
        "IN_LOCAL_FUNC_OUTROS",
        "IN_PREDIO_COMPARTILHADO",
    ],
    axis=1,
)

# %%
df6.to_csv("local_do_predio_escolar.csv", index=False)

# %%
df7 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_AGUA_POTAVEL",
        "IN_AGUA_REDE_PUBLICA",
        "IN_AGUA_POCO_ARTESIANO",
        "IN_AGUA_CACIMBA",
        "IN_AGUA_FONTE_RIO",
        "IN_AGUA_INEXISTENTE",
    ]
]

# %%
# Lista para armazenar os valores
agua = []

# Iterar pelas linhas do DataFrame
for _, row in df7.iterrows():
    if row["IN_AGUA_FONTE_RIO"] == 1:
        agua.append("Fonte/Rio/Igarapé/Riacho/Córrego")
    elif row["IN_AGUA_REDE_PUBLICA"] == 1:
        agua.append("Rede pública")
    elif row["IN_AGUA_POCO_ARTESIANO"] == 1:
        agua.append("Poço artesiano")
    elif row["IN_AGUA_CACIMBA"] == 1:
        agua.append("Cacimba/Cisterna/Poço")
    else:
        agua.append("Não há abastecimento de água")

# Adicionar a nova coluna ao DataFrame
df7["ABASTECIMENTO_AGUA"] = agua
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\2419081158.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7["ABASTECIMENTO_AGUA"] = agua

# %%
df7 = df7.drop(
    [
        "IN_AGUA_POTAVEL",
        "IN_AGUA_REDE_PUBLICA",
        "IN_AGUA_POCO_ARTESIANO",
        "IN_AGUA_POCO_ARTESIANO",
        "IN_AGUA_FONTE_RIO",
        "IN_AGUA_INEXISTENTE",
        "IN_AGUA_CACIMBA",
    ],
    axis=1,
)

# %%
df7.to_csv("abastecimento_de_agua.csv", index=False)

# %%
df8 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_ENERGIA_REDE_PUBLICA",
        "IN_ENERGIA_GERADOR_FOSSIL",
        "IN_ENERGIA_RENOVAVEL",
        "IN_ENERGIA_INEXISTENTE",
    ]
]

# %%
# Lista para armazenar os valores
energia = []

# Iterar pelas linhas do DataFrame
for _, row in df8.iterrows():
    if row["IN_ENERGIA_REDE_PUBLICA"] == 1:
        energia.append("Rede pública")
    elif row["IN_ENERGIA_GERADOR_FOSSIL"] == 1:
        energia.append("Gerador movido a combustível fóssil")
    elif row["IN_ENERGIA_RENOVAVEL"] == 1:
        energia.append(
            "Fontes de energia renováveis ou alternativas (gerador a biocombustível e/ou biodigestores, eólica, solar, outras)"
        )
    else:
        energia.append("Não há energia elétrica")

# Adicionar a nova coluna ao DataFrame
df8["ABASTECIMENTO_ENERGIA"] = energia
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\1929605048.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8["ABASTECIMENTO_ENERGIA"] = energia

# %%
df8 = df8.drop(
    [
        "IN_ENERGIA_REDE_PUBLICA",
        "IN_ENERGIA_GERADOR_FOSSIL",
        "IN_ENERGIA_RENOVAVEL",
        "IN_ENERGIA_INEXISTENTE",
    ],
    axis=1,
)

# %%
df8.to_csv("abastecimento_de_energia.csv", index=False)

# %%
df9 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "IN_ACESSIBILIDADE_CORRIMAO",
        "IN_ACESSIBILIDADE_ELEVADOR",
        "IN_ACESSIBILIDADE_PISOS_TATEIS",
        "IN_ACESSIBILIDADE_VAO_LIVRE",
        "IN_ACESSIBILIDADE_RAMPAS",
        "IN_ACESSIBILIDADE_SINAL_SONORO",
        "IN_ACESSIBILIDADE_SINAL_TATIL",
        "IN_ACESSIBILIDADE_SINAL_VISUAL",
        "IN_ACESSIBILIDADE_INEXISTENTE",
    ]
]

# %%
# Lista para armazenar os valores
soma_acessibilidade = []

# Iterar pelas linhas do DataFrame
for _, row in df9.iterrows():
    acessibilidade = 0
    if row["IN_ACESSIBILIDADE_CORRIMAO"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_ELEVADOR"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_PISOS_TATEIS"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_VAO_LIVRE"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_RAMPAS"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_SINAL_SONORO"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_SINAL_TATIL"] == 1:
        acessibilidade += 1
    if row["IN_ACESSIBILIDADE_SINAL_VISUAL"] == 1:
        acessibilidade += 1

    soma_acessibilidade.append(acessibilidade)

# Adicionar a nova coluna ao DataFrame
df9["TAXA_DE_ACESSIBILIDADE"] = soma_acessibilidade
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\4291360322.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9["TAXA_DE_ACESSIBILIDADE"] = soma_acessibilidade

# %%
df9 = df9.drop(
    [
        "IN_ACESSIBILIDADE_CORRIMAO",
        "IN_ACESSIBILIDADE_ELEVADOR",
        "IN_ACESSIBILIDADE_PISOS_TATEIS",
        "IN_ACESSIBILIDADE_VAO_LIVRE",
        "IN_ACESSIBILIDADE_RAMPAS",
        "IN_ACESSIBILIDADE_SINAL_SONORO",
        "IN_ACESSIBILIDADE_SINAL_TATIL",
        "IN_ACESSIBILIDADE_SINAL_VISUAL",
        "IN_ACESSIBILIDADE_INEXISTENTE",
    ],
    axis=1,
)

# %%
df9.to_csv("taxa_de_acesibilidade.csv", index=False)

# %%
df10 = df[
    [
        "NO_ENTIDADE",
        "CO_ENTIDADE",
        "DS_ENDERECO",
        "NU_ENDERECO",
        "DS_COMPLEMENTO",
        "NO_BAIRRO",
        "CO_CEP",
        "NU_DDD",
        "NU_TELEFONE",
    ]
]

# %%
df10.to_csv("endereços_e_contato.csv", index=False)

# %%
# Função para combinar todos os DataFrames com base na coluna 'CO_ENTIDADE'
dfs = [df2, df3, df4, df5, df6, df7, df8, df9, df10]
# Merge ignorando a coluna "NO_ENTIDADE"
df_merged1 = reduce(
    lambda left, right: pd.merge(
        left.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        right.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        on="CO_ENTIDADE",
    ),
    dfs,
)

# %%
df_names = df[
    [
        "NO_MUNICIPIO",
        "NO_UF",
        "SG_UF",
        "CO_DISTRITO",
        "NO_ENTIDADE",
        "CO_ENTIDADE",
    ]
]

# %%
df_merged0 = pd.merge(df11, df_merged1, on="CO_ENTIDADE", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df_merged0 = pd.merge(df11, df_merged1, on="CO_ENTIDADE", how="left")
#
# NameError: name 'df11' is not defined

# %%
df_merged0.to_csv("merged_incompleto1.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df_merged0.to_csv("merged_incompleto1.csv", index=False)
#
# NameError: name 'df_merged0' is not defined

# %%
df_merged0.to_json(
    "merged_incompleto0.json", orient="records", lines=True, force_ascii=False, indent=4
)

# %%
df12 = df[
    [
        "CO_ENTIDADE",
        "IN_ESGOTO_REDE_PUBLICA",
        "IN_ESGOTO_FOSSA_SEPTICA",
        "IN_ESGOTO_FOSSA_COMUM",
        "IN_ESGOTO_FOSSA",
        "IN_ESGOTO_INEXISTENTE",
    ]
]

# %%
# Lista para armazenar os valores
esgoto = []

# Iterar pelas linhas do DataFrame
for _, row in df12.iterrows():
    if row["IN_ESGOTO_REDE_PUBLICA"] == 1:
        esgoto.append("Rede pública")
    elif row["IN_ESGOTO_FOSSA_SEPTICA"] == 1:
        esgoto.append("Fossa Séptica")
    elif row["IN_ESGOTO_FOSSA_COMUM"] == 1:
        esgoto.append("Fossa comum")
    elif row["IN_ESGOTO_FOSSA"] == 1:
        esgoto.append("Fossa comum")
    else:
        esgoto.append("Não há tratamento de esgoto")

# Adicionar a nova coluna ao DataFrame
df12["ESGOTO"] = esgoto
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\1942153091.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12["ESGOTO"] = esgoto

# %%
df12 = df12.drop(
    [
        "IN_ESGOTO_REDE_PUBLICA",
        "IN_ESGOTO_FOSSA_SEPTICA",
        "IN_ESGOTO_FOSSA_COMUM",
        "IN_ESGOTO_FOSSA",
        "IN_ESGOTO_INEXISTENTE",
    ],
    axis=1,
)

# %%
df12.to_csv("esgoto.csv", index=False)

# %%
df13 = df[
    [
        "CO_ENTIDADE",
        "IN_AREA_VERDE",
        "IN_BIBLIOTECA",
        "IN_LABORATORIO_CIENCIAS",
        "IN_LABORATORIO_INFORMATICA",
        "IN_LABORATORIO_EDUC_PROF",
        "IN_PISCINA",
        "IN_QUADRA_ESPORTES",
        "IN_SALA_ATELIE_ARTES",
        "IN_SALA_MUSICA_CORAL",
        "IN_SALA_ESTUDIO_DANCA",
        "IN_SALA_ESTUDIO_GRAVACAO",
        "IN_SALA_OFICINAS_EDUC_PROF",
        "IN_VIVEIRO",
    ]
]

# %%
# Lista para armazenar os valores
soma_infraestrutura = []

# Iterar pelas linhas do DataFrame
for _, row in df13.iterrows():
    infraestrutura = 0
    if row["IN_AREA_VERDE"] == 1:
        infraestrutura += 1
    if row["IN_BIBLIOTECA"] == 1:
        infraestrutura += 1
    if row["IN_LABORATORIO_CIENCIAS"] == 1:
        infraestrutura += 1
    if row["IN_LABORATORIO_INFORMATICA"] == 1:
        infraestrutura += 1
    if row["IN_LABORATORIO_EDUC_PROF"] == 1:
        infraestrutura += 1
    if row["IN_PISCINA"] == 1:
        infraestrutura += 1
    if row["IN_QUADRA_ESPORTES"] == 1:
        infraestrutura += 1
    if row["IN_SALA_ATELIE_ARTES"] == 1:
        infraestrutura += 1
    if row["IN_SALA_MUSICA_CORAL"] == 1:
        infraestrutura += 1
    if row["IN_SALA_ESTUDIO_DANCA"] == 1:
        infraestrutura += 1
    if row["IN_SALA_ESTUDIO_GRAVACAO"] == 1:
        infraestrutura += 1
    if row["IN_SALA_OFICINAS_EDUC_PROF"] == 1:
        infraestrutura += 1
    if row["IN_VIVEIRO"] == 1:
        infraestrutura += 1

    soma_infraestrutura.append(infraestrutura)

# Adicionar a nova coluna ao DataFrame
df13["TAXA_DE_INFRAESTRUTURA"] = soma_infraestrutura
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\1225201833.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13["TAXA_DE_INFRAESTRUTURA"] = soma_infraestrutura

# %%
# Dicionário com as infraestruturas e suas representações em string
infraestrutura_dict = {
    "IN_AREA_VERDE": "Área Verde",
    "IN_BIBLIOTECA": "Biblioteca",
    "IN_LABORATORIO_CIENCIAS": "Laboratório de Ciências",
    "IN_LABORATORIO_INFORMATICA": "Laboratório de Informática",
    "IN_LABORATORIO_EDUC_PROF": "Laboratório Educacional Profissional",
    "IN_PISCINA": "Piscina",
    "IN_QUADRA_ESPORTES": "Quadra de Esportes",
    "IN_SALA_ATELIE_ARTES": "Sala de Ateliê de Artes",
    "IN_SALA_MUSICA_CORAL": "Sala de Música e Coral",
    "IN_SALA_ESTUDIO_DANCA": "Sala de Estúdio de Dança",
    "IN_SALA_ESTUDIO_GRAVACAO": "Sala de Estúdio de Gravação",
    "IN_SALA_OFICINAS_EDUC_PROF": "Sala de Oficinas de Educação Profissional",
    "IN_VIVEIRO": "Viveiro/Criação de animais",
}

# Lista para armazenar as listas de infraestruturas
infraestrutura_list = []

# Iterar pelas linhas do DataFrame
for _, row in df13.iterrows():
    infraestrutura = []

    # Verificar cada infraestrutura, e se o valor for 1, adicionar a string correspondente
    for coluna, nome in infraestrutura_dict.items():
        if row[coluna] == 1:
            infraestrutura.append(nome)

    # Adicionar a lista de infraestrutura para o índice correspondente
    infraestrutura_list.append(infraestrutura)

# Adicionar a nova coluna ao DataFrame
df13["LISTA_INFRAESTRUTURAS"] = infraestrutura_list
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\2840983879.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13["LISTA_INFRAESTRUTURAS"] = infraestrutura_list

# %%
df13 = df13.drop(
    [
        "IN_AREA_VERDE",
        "IN_BIBLIOTECA",
        "IN_LABORATORIO_CIENCIAS",
        "IN_LABORATORIO_INFORMATICA",
        "IN_LABORATORIO_EDUC_PROF",
        "IN_PISCINA",
        "IN_QUADRA_ESPORTES",
        "IN_SALA_ATELIE_ARTES",
        "IN_SALA_MUSICA_CORAL",
        "IN_SALA_ESTUDIO_DANCA",
        "IN_SALA_ESTUDIO_GRAVACAO",
        "IN_SALA_OFICINAS_EDUC_PROF",
        "IN_VIVEIRO",
    ],
    axis=1,
)

# %%
df13.to_csv("infraestrutura.csv", index=False)

# %%
df14 = df[
    [
        "CO_ENTIDADE",
        "IN_PROF_FONAUDIOLOGO",
        "IN_PROF_NUTRICIONISTA",
        "IN_PROF_PSICOLOGO",
        "IN_PROF_SEGURANCA",
        "IN_PROF_MONITORES",
        "IN_PROF_ASSIST_SOCIAL",
        "IN_PROF_TRAD_LIBRAS",
    ]
]

# %%
# Dicionário com as infraestruturas e suas representações em string
profissionais_dict = {
    "IN_PROF_FONAUDIOLOGO": "Fonoaudiólogo",
    "IN_PROF_NUTRICIONISTA": "Nutricionista",
    "IN_PROF_PSICOLOGO": "Psicólogo",
    "IN_PROF_SEGURANCA": "Segurança/Guarda",
    "IN_PROF_MONITORES": "Técnicos de apoio a tecnologias educacionais",
    "IN_PROF_ASSIST_SOCIAL": "Assistência Social",
    "IN_PROF_TRAD_LIBRAS": "Tradutor e intérprete de Libras",
}

# Lista para armazenar as listas de infraestruturas
profissionais_list = []

# Iterar pelas linhas do DataFrame
for _, row in df14.iterrows():
    profissionais = []

    # Verificar cada infraestrutura, e se o valor for 1, adicionar a string correspondente
    for coluna, nome in profissionais_dict.items():
        if row[coluna] == 1:
            profissionais.append(nome)

    # Adicionar a lista de infraestrutura para o índice correspondente
    profissionais_list.append(profissionais)

# Adicionar a nova coluna ao DataFrame
df14["LISTA_PROFISSIONAIS"] = profissionais_list
# Out:
# C:\Users\Georgia Cavallaro\AppData\Local\Temp\ipykernel_12120\2875751202.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14["LISTA_PROFISSIONAIS"] = profissionais_list

# %%
df14 = df14.drop(
    [
        "IN_PROF_FONAUDIOLOGO",
        "IN_PROF_NUTRICIONISTA",
        "IN_PROF_PSICOLOGO",
        "IN_PROF_SEGURANCA",
        "IN_PROF_MONITORES",
        "IN_PROF_ASSIST_SOCIAL",
        "IN_PROF_TRAD_LIBRAS",
    ],
    axis=1,
)

# %%
df14.to_csv("corpo_docente.csv", index=False)

# %%
# Função para combinar todos os DataFrames com base na coluna 'CO_ENTIDADE'
dfs = [df2, df3, df4, df5, df6, df7, df8, df9, df10, df12, df13, df14]
# Merge ignorando a coluna "NO_ENTIDADE"
df_merged2 = reduce(
    lambda left, right: pd.merge(
        left.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        right.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        on="CO_ENTIDADE",
    ),
    dfs,
)

# %%
df_merged_brasil = pd.merge(df_names, df_merged2, on="CO_ENTIDADE", how="left")

# %%
df_merged_brasil.to_csv("merged_brasil.csv", index=False)

# %%
df_cidade_sao_paulo = df_merged_brasil[df_merged_brasil["NO_MUNICIPIO"] == "São Paulo"]

# %%
df_cidade_sao_paulo.to_csv("merged_cidade_sp.csv", index=False)

# %%
df_cidade_sao_paulo.to_json(
    "merged_cidade_sp.json", orient="records", lines=True, force_ascii=False, indent=4
)

# %%
df_coordenadas = pd.read_csv(
    "dados_coord_geo.csv", encoding="ISO-8859-1", sep=",", low_memory=False
)

# %%
# Função para combinar todos os DataFrames com base na coluna 'CO_ENTIDADE'
dfs = [
    df_coordenadas,
    df1,
    df2,
    df3,
    df4,
    df5,
    df6,
    df7,
    df8,
    df9,
    df10,
    df12,
    df13,
    df14,
]
# Merge ignorando a coluna "NO_ENTIDADE"
df_merged3 = reduce(
    lambda left, right: pd.merge(
        left.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        right.drop(columns=["NO_ENTIDADE"], errors="ignore"),
        on="CO_ENTIDADE",
    ),
    dfs,
)

# %%
df_merged_brasil = pd.merge(df_names, df_merged3, on="CO_ENTIDADE", how="left")

# %%
df_merged_brasil.to_csv("merged_brasil.csv", index=False)

# %%
df_merged_brasil
# Out:
#        NO_MUNICIPIO             NO_UF SG_UF  CO_DISTRITO  \
# 0       Porto Velho          Rondônia    RO    110020505
# 1       Porto Velho          Rondônia    RO    110020505
# 2       Porto Velho          Rondônia    RO    110020505
# 3       Porto Velho          Rondônia    RO    110020505
# 4       Porto Velho          Rondônia    RO    110020505
# ...             ...               ...   ...          ...
# 217620     Brasília  Distrito Federal    DF    530010805
# 217621     Brasília  Distrito Federal    DF    530010805
# 217622     Brasília  Distrito Federal    DF    530010805
# 217623     Brasília  Distrito Federal    DF    530010805
# 217624     Brasília  Distrito Federal    DF    530010805
#
#                                             NO_ENTIDADE  CO_ENTIDADE  \
# 0                    EEEE ABNAEL MACHADO DE LIMA - CENE     11000023
# 1                              EMEIEF PEQUENOS TALENTOS     11000040
# 2                             CENTRO DE ENSINO CLASSE A     11000058
# ...

# %%
df_estado_sp = df_merged_brasil[df_merged_brasil["SG_UF"] == "SP"]

# %%
df_estado_sp.to_csv("merged_uf_sp.csv", index=False)

# %%
df_estado_sp.to_json(
    "merged_uf_sp.json", orient="records", lines=True, force_ascii=False, indent=4
)

# %%
df_enem = pd.read_csv(
    "enem_data_ideb_filtrados_sp.csv", encoding="ISO-8859-1", sep=",", low_memory=False
)

# %%
df_enem.rename(
    columns={"CO_MUNICIPIO_ESC": "CO_ENTIDADE"},
    inplace=True,
)

# %%
df_estado_sp3 = pd.merge(
    df_estado_sp, df_enem[["CO_ENTIDADE", "IDEB_2023"]], on="CO_ENTIDADE", how="left"
)

# %%
df_estado_sp3.to_csv("merged_uf_sp_enem.csv", index=False)

# %%
df_estado_sp3.to_json(
    "merged_estado_sp_enem.json",
    orient="records",
    lines=True,
    force_ascii=False,
    indent=4,
)

# %%
df_estado_sp3
# Out:
#            NO_MUNICIPIO      NO_UF SG_UF  CO_DISTRITO  \
# 0             São Paulo  São Paulo    SP    355030840
# 1             São Paulo  São Paulo    SP    355030861
# 2             São Paulo  São Paulo    SP    355030829
# 3             São Paulo  São Paulo    SP    355030811
# 4             São Paulo  São Paulo    SP    355030803
# ...                 ...        ...   ...          ...
# 34094   Santa Fé do Sul  São Paulo    SP    354660305
# 34095            Franca  São Paulo    SP    351620005
# 34096     Fernandópolis  São Paulo    SP    351550905
# 34097  Igaraçu do Tietê  São Paulo    SP    352000405
# 34098         São Paulo  São Paulo    SP    355030856
#
#                                   NO_ENTIDADE  CO_ENTIDADE  longitude  \
# 0                    AYRES DE MOURA PROFESSOR     35000012 -46.749710
# 1                   GAVIAO PEIXOTO BRIGADEIRO     35000024 -46.759380
# 2                                JOAO SOLIMEO     35000036 -46.698399
# ...
